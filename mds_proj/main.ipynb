# %%
# !cp -r /kaggle/input/main-code /kaggle/working/src

# %%
# !pip install python-dotenv

import os
from dotenv import load_dotenv

load_dotenv()

token = os.getenv("GITHUB_TOKEN")

repo_url = f"https://{token}@github.com/Louis-26/GPT2-fine-tune.git"

# %cd /kaggle/working/
# !git clone {repo_url}
# Out:
# /kaggle/working
# fatal: destination path 'GPT2-fine-tune' already exists and is not an empty directory.

# %%
# check the gpu setting
# !nvidia-smi
# Out:
# Sat Jun 27 23:58:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   42C    P8             14W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # step 1: configure the environment

# %%
# NOTE: Make sure you have added the dataset into the notebook
# Move the code to working directory
# !cp -r /kaggle/input/main-code /kaggle/working/src

# # Move the dataset to working directory
# !cp -r /kaggle/input/finetuning-dataset/src/* /kaggle/working/src

# install necessary packages, as Kaggle will clear installed packages when restart the kernel.
# %cd /kaggle/working/GPT2-fine-tune/mds_proj
# %pip install -r src/requirements.txt

# %cd /kaggle/working/src
# !ls
# Out:
# /kaggle/working/GPT2-fine-tune/mds_proj
# Requirement already satisfied: absl-py==1.4.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: accelerate==0.16.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: aiohttp==3.8.4 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 3)) (3.8.4)
# Requirement already satisfied: aiosignal==1.3.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: async-timeout==4.0.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 5)) (4.0.2)
# Requirement already satisfied: attrs==22.2.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 6)) (22.2.0)
# Requirement already satisfied: blobfile==2.0.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: cachetools==5.3.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 8)) (5.3.0)
# Requirement already satisfied: certifi==2022.12.7 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 9)) (2022.12.7)
# Requirement already satisfied: charset-normalizer==2.1.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 10)) (2.1.1)
# Requirement already satisfied: click==8.1.3 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 11)) (8.1.3)
# Requirement already satisfied: cmake==3.25.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 12)) (3.25.0)
# Requirement already satisfied: datasets==2.10.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 13)) (2.10.0)
# Requirement already satisfied: dill==0.3.6 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 14)) (0.3.6)
# Requirement already satisfied: filelock==3.9.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 15)) (3.9.0)
# Requirement already satisfied: frozenlist==1.3.3 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 16)) (1.3.3)
# Requirement already satisfied: fsspec==2023.1.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 17)) (2023.1.0)
# Requirement already satisfied: google-auth==2.16.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 18)) (2.16.1)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 19)) (0.4.6)
# Requirement already satisfied: grpcio==1.51.3 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 20)) (1.51.3)
# Requirement already satisfied: huggingface-hub==0.12.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 21)) (0.12.1)
# Requirement already satisfied: idna==3.4 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 22)) (3.4)
# Requirement already satisfied: Jinja2==3.1.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 23)) (3.1.2)
# Requirement already satisfied: langchain==0.0.115 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 24)) (0.0.115)
# Requirement already satisfied: lit==15.0.7 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 25)) (15.0.7)
# Requirement already satisfied: loralib==0.1.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 26)) (0.1.1)
# Requirement already satisfied: lxml==4.9.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 27)) (4.9.2)
# Requirement already satisfied: Markdown==3.4.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 28)) (3.4.1)
# Requirement already satisfied: MarkupSafe==2.1.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 29)) (2.1.2)
# Requirement already satisfied: mpmath==1.2.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 30)) (1.2.1)
# Requirement already satisfied: multidict==6.0.4 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 31)) (6.0.4)
# Requirement already satisfied: multiprocess==0.70.14 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 32)) (0.70.14)
# Requirement already satisfied: networkx==3.0rc1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 33)) (3.0rc1)
# Requirement already satisfied: numpy==1.24.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 34)) (1.24.1)
# Requirement already satisfied: oauthlib==3.2.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 35)) (3.2.2)
# Requirement already satisfied: openai==0.27.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 36)) (0.27.2)
# Requirement already satisfied: packaging==23.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 37)) (23.0)
# Requirement already satisfied: pandas==1.5.3 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 38)) (1.5.3)
# Requirement already satisfied: Pillow==9.3.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 39)) (9.3.0)
# Collecting protobuf==4.22.0 (from -r src/requirements.txt (line 40))
#   Using cached protobuf-4.22.0-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Requirement already satisfied: psutil==5.9.4 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 41)) (5.9.4)
# Requirement already satisfied: pyarrow==11.0.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 42)) (11.0.0)
# Requirement already satisfied: pyasn1==0.4.8 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 43)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 44)) (0.2.8)
# Requirement already satisfied: pycryptodomex==3.17 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 45)) (3.17)
# Requirement already satisfied: python-dateutil==2.8.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 46)) (2.8.2)
# Requirement already satisfied: pytz==2022.7.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 47)) (2022.7.1)
# Requirement already satisfied: PyYAML==6.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 48)) (6.0)
# Requirement already satisfied: regex==2022.10.31 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 49)) (2022.10.31)
# Requirement already satisfied: requests==2.28.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 50)) (2.28.1)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 51)) (1.3.1)
# Requirement already satisfied: responses==0.18.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 52)) (0.18.0)
# Requirement already satisfied: rsa==4.9 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 53)) (4.9)
# Requirement already satisfied: six==1.16.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 54)) (1.16.0)
# Requirement already satisfied: sympy==1.11.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 55)) (1.11.1)
# Requirement already satisfied: tensorboard==2.12.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 56)) (2.12.0)
# Requirement already satisfied: tensorboard-data-server==0.7.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 57)) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 58)) (1.8.1)
# Requirement already satisfied: tiktoken==0.2.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 59)) (0.2.0)
# Requirement already satisfied: tokenizers==0.13.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 60)) (0.13.2)
# Requirement already satisfied: torchinfo==1.7.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 61)) (1.7.2)
# Requirement already satisfied: sentencepiece==0.1.97 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 66)) (0.1.97)
# Requirement already satisfied: tqdm==4.64.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 67)) (4.64.1)
# Requirement already satisfied: transformers==4.26.1 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 68)) (4.26.1)
# Requirement already satisfied: typing_extensions==4.4.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 69)) (4.4.0)
# Requirement already satisfied: urllib3==1.26.13 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 70)) (1.26.13)
# Requirement already satisfied: Werkzeug==2.2.3 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 71)) (2.2.3)
# Requirement already satisfied: xxhash==3.2.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 72)) (3.2.0)
# Requirement already satisfied: yapf==0.32.0 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 73)) (0.32.0)
# Requirement already satisfied: yarl==1.8.2 in /opt/conda/lib/python3.10/site-packages (from -r src/requirements.txt (line 74)) (1.8.2)
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from accelerate==0.16.0->-r src/requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: SQLAlchemy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain==0.0.115->-r src/requirements.txt (line 24)) (1.4.54)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from langchain==0.0.115->-r src/requirements.txt (line 24)) (0.5.14)
# Requirement already satisfied: pydantic<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain==0.0.115->-r src/requirements.txt (line 24)) (1.10.26)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain==0.0.115->-r src/requirements.txt (line 24)) (8.2.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard==2.12.0->-r src/requirements.txt (line 56)) (69.0.3)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.10/site-packages (from tensorboard==2.12.0->-r src/requirements.txt (line 56)) (0.42.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.115->-r src/requirements.txt (line 24)) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.115->-r src/requirements.txt (line 24)) (0.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<2,>=1->langchain==0.0.115->-r src/requirements.txt (line 24)) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.115->-r src/requirements.txt (line 24)) (1.0.0)
# Using cached protobuf-4.22.0-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.12
#     Uninstalling protobuf-4.21.12:
#       Successfully uninstalled protobuf-4.21.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.6 which is incompatible.
# apache-beam 2.46.0 requires protobuf<4,>3.12.2, but you have protobuf 4.22.0 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 23.0 which is incompatible.
# google-cloud-bigquery 2.34.4 requires protobuf<4.0.0dev,>=3.12.0, but you have protobuf 4.22.0 which is incompatible.
# google-cloud-bigtable 1.7.3 requires protobuf<4.0.0dev, but you have protobuf 4.22.0 which is incompatible.
# google-cloud-vision 2.8.0 requires protobuf<4.0.0dev,>=3.19.0, but you have protobuf 4.22.0 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# kfp 2.5.0 requires protobuf<4,>=3.13.0, but you have protobuf 4.22.0 which is incompatible.
# kfp-pipeline-spec 0.2.2 requires protobuf<4,>=3.13.0, but you have protobuf 4.22.0 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# tensorflow 2.15.0 requires tensorboard<2.16,>=2.15, but you have tensorboard 2.12.0 which is incompatible.
# tensorflow-metadata 0.14.0 requires protobuf<4,>=3.7, but you have protobuf 4.22.0 which is incompatible.
# tensorflow-transform 0.14.0 requires protobuf<4,>=3.7, but you have protobuf 4.22.0 which is incompatible.
# Successfully installed protobuf-4.22.0
# Note: you may need to restart the kernel to use updated packages.
# [Errno 2] No such file or directory: '/kaggle/working/src'
# /kaggle/working/GPT2-fine-tune/mds_proj
# Kaggle_training.md		error.md
# README.md			kernel-metadata-template.json
# dataset-metadata-template.json	kernel-metadata.json
# dataset-metadata.json		main.ipynb
# derive_loss.ipynb		src
# derive_score.ipynb

# %% [markdown]
# # step 2: download dataset

# %%
import os
import json

kaggle_creds = {"username":"louis26","key":"875abc09bd313870ed253e05e7d5e280"}

os.makedirs('/root/.kaggle', exist_ok=True)
with open('/root/.kaggle/kaggle.json', 'w') as f:
    json.dump(kaggle_creds, f)

# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d jonery/finetuning-dataset -p /kaggle/working/GPT2-fine-tune/mds_proj/src

# %cd /kaggle/working/GPT2-fine-tune/mds_proj/src

# !unzip -o -q finetuning-dataset.zip

# !rm finetuning-dataset.zip
# !mv src/* .
# !ls -l
# Out:
# Downloading finetuning-dataset.zip to /kaggle/working/GPT2-fine-tune/mds_proj/src
#  99%|███████████████████████████████████████▍| 109M/110M [00:06<00:00, 23.6MB/s]
# 100%|████████████████████████████████████████| 110M/110M [00:06<00:00, 18.0MB/s]
# /kaggle/working/GPT2-fine-tune/mds_proj/src
# total 328672
# -rw-r--r-- 1 root root         0 Jun 27 23:32 __init__.py
# drwxr-xr-x 2 root root      4096 Jun 27 23:59 __pycache__
# -rw-r--r-- 1 root root    421515 Nov 12  2023 chatgpt_preferences.json
# -rw-r--r-- 1 root root      4395 Jun 27 23:32 configs.py
# -rw-r--r-- 1 root root       117 Nov 12  2023 dataset-metadata.json
# -rw-r--r-- 1 root root     14908 Jun 27 23:32 dataset.py
# -rw-r--r-- 1 root root   8537526 Nov 12  2023 dataset_hhrlhf_test.json
# -rw-r--r-- 1 root root 159301790 Nov 12  2023 dataset_hhrlhf_train.json
# -rw-r--r-- 1 root root   4802465 Nov 12  2023 dataset_rmstatic_test.json
# -rw-r--r-- 1 root root  71452971 Nov 12  2023 dataset_rmstatic_train.json
# -rw-r--r-- 1 root root      3762 Jun 27 23:32 evaluate.py
# -rw-r--r-- 1 root root     24275 Jun 27 23:32 gpt.py
# -rw-r--r-- 1 root root     10449 Jun 27 23:32 judge_prompts.jsonl
# -rw-r--r-- 1 root root       346 Jun 27 23:32 kernel-metadata.json
# drwxr-xr-x 2 root root      4096 Jun 27 23:32 latest_code
# -rw-r--r-- 1 root root      1501 Jun 27 23:32 prepare_sft_dataset.py
# -rw-r--r-- 1 root root      1346 Jun 27 23:32 requirements.txt
# -rw-r--r-- 1 root root    276131 Nov 12  2023 responses.json
# drwxr-xr-x 4 root root      4096 Jun 27 23:32 runs
# -rw-r--r-- 1 root root   3737447 Nov 12  2023 sft_test.json
# -rw-r--r-- 1 root root  87894850 Nov 12  2023 sft_train.json
# drwxr-xr-x 2 root root      4096 Jun 28 01:06 src
# -rw-r--r-- 1 root root       927 Jun 27 23:32 tokenizer.py
# -rw-r--r-- 1 root root      1764 Jun 27 23:32 train_sft.py
# -rw-r--r-- 1 root root      5028 Jun 27 23:32 trainers.py
# -rw-r--r-- 1 root root       306 Jun 27 23:32 utils.py

# %% [markdown]
# # step 3: training

# %%
# NOTE: Make sure you turn on the GPU when running the script
# TODO: Change this line to the script you want to execute
# !python <script_name.py> 

# e.g. 
# %cd /kaggle/working/GPT2-fine-tune/mds_proj/src
# !python train_sft.py --model-type gpt2-medium --pretrain huggingface --batch-size 16 --exp-name lora_ft_exp --use-lora
# Out:
# /kaggle/working/GPT2-fine-tune/mds_proj/src
# 2026-06-28 01:42:01.706756: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-06-28 01:42:01.706815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-06-28 01:42:01.708396: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ^C
#
# Aborted!
